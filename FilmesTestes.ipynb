# %% [markdown]
# # TMDB primeiras visualizações

# %%
import pandas as pd

tmdb = pd.read_csv('./dados/tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

# %%
ax = sns.distplot(tmdb.vote_average)
ax.set(xlabel = "Nota média", ylabel ="Densidade", title = "Média de votos")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\1791906684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Média de votos')]

# %%
ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
ax.set(xlabel = "Nota média", ylabel ="Frequencia", title = "Média de votos")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\1349548337.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Frequencia'),
#  Text(0.5, 1.0, 'Média de votos')]

# %%
ax = sns.boxplot(x = tmdb.vote_average)
ax.set(title = "Distribuição das notas médias", xlabel = "Nota média do filme")
# Out:
# [Text(0.5, 1.0, 'Distribuição das notas médias'),
#  Text(0.5, 0, 'Nota média do filme')]

# %% [markdown]
# ### Filmes que tiveram mais que 10 votos

# %%
tmdb.query("vote_average == 0").head()
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# 3852                            NaN  395766
# 3855    http://www.timetochoose.com  370662
#
#                                                keywords original_language  \
# 1464                                                 []                en
# 3669                                                 []                en
# 3670                                                 []                en
# ...

# %%
maior_que_10 = tmdb.query("vote_count >=10 ")
maior_que_10.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax = sns.distplot(maior_que_10.vote_average)
ax.set(xlabel = "Nota média", ylabel ="Frequencia", title = "Média de votos com mais votos")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2376220393.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(maior_que_10.vote_average)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Frequencia'),
#  Text(0.5, 1.0, 'Média de votos com mais votos')]

# %%
ax = sns.boxplot(x = maior_que_10.vote_average)
ax.set(title = "Distribuição das notas médias", xlabel = "Nota média do filme com mais votos")
# Out:
# [Text(0.5, 1.0, 'Distribuição das notas médias'),
#  Text(0.5, 0, 'Nota média do filme com mais votos')]

# %% [markdown]
# # MovieLens

# %%
notas = pd.read_csv('./dados/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_filme = notas.groupby("movieId").mean()["rating"]
nota_media_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_filme.values)
ax.set(xlabel = "Nota média", ylabel ="Densidade", title = "Média de votos")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\594619764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_filme.values)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Média de votos')]

# %%
votos_por_filme = notas.groupby("movieId").count()
mais_que_10 = votos_por_filme.query("rating >= 10 ").index
mais_que_10.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], shape=(2269,))

# %%
nota_media_maior_que_10 = nota_media_filme.loc[mais_que_10.values]
nota_media_maior_que_10.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_maior_que_10)
ax.set(xlabel = "Nota média", ylabel ="Densidade", title = "Média de votos mais votados")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\3884440883.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_maior_que_10)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Média de votos mais votados')]

# %%
sns.set_palette("BuPu_r")
sns.set_style("darkgrid")

# %%
ax = sns.distplot(nota_media_maior_que_10.values,
                  hist_kws = {'cumulative': True},
                  kde_kws={'cumulative': True})
ax.set(xlabel = "Nota média", ylabel ="Densidade",
       title = "% Acumulada das notas do filme ")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\972142921.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_maior_que_10.values,
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, '% Acumulada das notas do filme ')]

# %%
ax = sns.boxplot(x = nota_media_maior_que_10.values)
ax.set(title = "Distribuição das notas médias", xlabel = "Nota média do filme com mais votos")
# Out:
# [Text(0.5, 1.0, 'Distribuição das notas médias'),
#  Text(0.5, 0, 'Nota média do filme com mais votos')]

# %% [markdown]
# # TMDB outros campos

# %%
ax = sns.distplot(maior_que_10.vote_count)
ax.set(xlabel = "Numero de votos", ylabel ="Densidade",
       title = "Numero de votos no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\3480175393.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(maior_que_10.vote_count)
# [Text(0.5, 0, 'Numero de votos'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Numero de votos no TMDB')]

# %%
ax = sns.distplot(tmdb.query("budget > 0").budget)
ax.set(xlabel = "Budget", ylabel ="Densidade",
       title = "Gastos dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2639910506.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query("budget > 0").budget)
# [Text(0.5, 0, 'Budget'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Gastos dos filmes no TMDB')]

# %%
ax = sns.distplot(tmdb.popularity)
ax.set(xlabel = "Popularidade", ylabel ="Densidade",
       title = "Poupularidade dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\3800018182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.popularity)
# [Text(0.5, 0, 'Popularidade'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Poupularidade dos filmes no TMDB')]

# %%
ax = sns.distplot(tmdb.runtime)
ax.set(xlabel = "Tempo", ylabel ="Densidade",
       title = "Tempo de duração dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2670102028.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.runtime)
# [Text(0.5, 0, 'Tempo'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Tempo de duração dos filmes no TMDB')]

# %%
tmdb.runtime.isnull().sum()
# Out:
# np.int64(2)

# %%
tmdb.runtime.dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
ax = sns.distplot(tmdb.runtime)
ax.set(xlabel = "Tempo", ylabel ="Densidade",
       title = "Tempo de duração dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2670102028.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.runtime)
# [Text(0.5, 0, 'Tempo'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Tempo de duração dos filmes no TMDB')]

# %%
tmdb.query("runtime == 0")
# Out:
#        budget                                             genres  \
# 1011        0                     [{"id": 27, "name": "Horror"}]
# 3112        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3809  4000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3953        0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
# 3992        0                                                 []
# 4068        0                                                 []
# 4118        0                                                 []
# 4205        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 4210        0                 [{"id": 10749, "name": "Romance"}]
# 4241  1500000                     [{"id": 35, "name": "Comedy"}]
# 4313        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4318        0                     [{"id": 27, "name": "Horror"}]
# ...

# %%
ax = sns.distplot(tmdb.query("runtime > 0").runtime.dropna())
ax.set(xlabel = "Tempo", ylabel ="Densidade",
       title = "Tempo de duração dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\902454033.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query("runtime > 0").runtime.dropna())
# [Text(0.5, 0, 'Tempo'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Tempo de duração dos filmes no TMDB')]

# %%
ax = sns.distplot(tmdb.query("runtime > 0").runtime.dropna(),
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True})
ax.set(xlabel = "Tempo", ylabel ="% de filmes",
       title = "Tempo de duração dos filmes no TMDB")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2439659250.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query("runtime > 0").runtime.dropna(),
# [Text(0.5, 0, 'Tempo'),
#  Text(0, 0.5, '% de filmes'),
#  Text(0.5, 1.0, 'Tempo de duração dos filmes no TMDB')]

# %%
tmdb.query("runtime > 0").runtime.dropna().quantile(0.8)
# Out:
# np.float64(121.0)

# %% [markdown]
# ### MovieLens com mais que 10 votos

# %%
import matplotlib.pyplot as plt

# %%
print("Média das notas dos filmes no MovieLens com pelo menos 10 votos é: ", nota_media_maior_que_10.mean())
# Out:
# Média das notas dos filmes no MovieLens com pelo menos 10 votos é:  3.4320503405352594

# %%
nota_media_maior_que_10[0:5].mean()
# Out:
# np.float64(3.5259741603585653)

# %%
temp = nota_media_maior_que_10.sample(frac=1)
import numpy as np
np.random.seed(75243)

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_maior_que_10)
# Out:
# (np.float64(3.4112459477469557), np.float64(3.452854733323563))

# %%
from statsmodels.stats.weightstats import DescrStatsW
descr_todos_com_10_votos = DescrStatsW(nota_media_maior_que_10)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (np.float64(3.411234839229381), np.float64(3.4528658418411395))

# %% [markdown]
# #Filme 1

# %%
filmes = pd.read_csv('./dados/movies.csv')
filmes.query("movieId == 1")
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query("movieId == 1")
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.distplot(notas1.rating)
ax.set(xlabel = "Nota média", ylabel ="Densidade",
       title = "Distribuição das notas de Toy Story")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\761452678.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(notas1.rating)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Distribuição das notas de Toy Story')]

# %%
ax = sns.boxplot(x = notas1.rating)
ax.set(xlabel = "Nota",
       title = "Distribuição das notas de Toy Story")
# Out:
# [Text(0.5, 0, 'Nota'), Text(0.5, 1.0, 'Distribuição das notas de Toy Story')]

# %%
notas1.rating.mean()
# Out:
# np.float64(3.9209302325581397)

# %%
notas1.rating.count()
# Out:
# np.int64(215)

# %%
  zconfint(notas1.rating)
# Out:
# (np.float64(3.8093359183563402), np.float64(4.032524546759939))

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(notas1.rating, value = 3.4320503405352594)
# Out:
# (np.float64(8.586342305916732), np.float64(8.97819040188565e-18))

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
  media = temp[0:i].mean()
  stat, p = ztest(temp[0:i], value = 3.4320503405352594)
  return (i, media, p)


valores = np.array([calcula_teste(i) for i in range(2, len(temp))])
plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2])
plt.hlines( y = 0.05, colors ='r', xmin = 2, xmax = len(temp))

# %% [markdown]
# se usasse um conjunto menor, a média seria muito instável, assim que o P value fica menor que 0.05, os dados ficam mais confiáveis

# %% [markdown]
# ### Comparação de dois conjuntos de amostras

# %%
print(ztest(notas1.rating , notas.rating))
zconfint(notas1.rating , notas.rating)
# Out:
# (np.float64(5.894327101501841), np.float64(3.762112778881965e-09))
# (np.float64(0.2799245129192442), np.float64(0.5588219849631111))

# %%
print(ztest(notas.rating , notas1.rating))
zconfint(notas.rating , notas1.rating)
# Out:
# (np.float64(-5.894327101501841), np.float64(3.762112778881965e-09))
# (np.float64(-0.5588219849631111), np.float64(-0.2799245129192442))

# %%
from scipy.stats import ttest_ind

ttest_ind(notas.rating, notas1.rating)
# Out:
# TtestResult(statistic=np.float64(-5.894327101501841), pvalue=np.float64(3.774003138720876e-09), df=np.float64(101049.0))

# %%
descr_todas_notas = DescrStatsW(notas.rating)
desc_toystory = DescrStatsW(notas1.rating)

comparacao  = descr_todas_notas.get_compare(desc_toystory)

print (comparacao.summary())
# Out:
#                           Test for equality of means
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1     -0.4194      0.071     -5.894      0.000      -0.559      -0.280
# ...

# %%
plt.boxplot([notas.rating, notas1.rating], labels = ["Todas as notas", "Toy Story"])
plt.title("Distribuição das notas")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\2487936640.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([notas.rating, notas1.rating], labels = ["Todas as notas", "Toy Story"])
# Text(0.5, 1.0, 'Distribuição das notas')

# %%
filmes.query("movieId in [1, 593, 72226]")
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas1 = notas.query("movieId == 1")
notas593 = notas.query("movieId == 593")
notas72226 = notas.query("movieId == 72226")

plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels = ["Toy Story", "Silence of the Lambs", "Fantastic Mr. Fox"])
plt.title("Distribuição das notas")
# Out:
# C:\Users\rafael.inforsato\AppData\Local\Temp\ipykernel_24032\221027142.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels = ["Toy Story", "Silence of the Lambs", "Fantastic Mr. Fox"])
# Text(0.5, 1.0, 'Distribuição das notas')

# %%
sns.boxplot(x = "movieId", y = "rating", data = notas.query("movieId in [1, 593, 72226]"))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
#toystory e silence of lambs
desc_1 = DescrStatsW(notas1.rating)
desc_593 = DescrStatsW(notas593.rating)

comparacao  = desc_1.get_compare(desc_593)

print (comparacao.summary())
# Out:
#                           Test for equality of means
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1     -0.2404      0.077     -3.132      0.002      -0.391      -0.090
# ...

# %%
#silence of lambs e fantastic mr fox
desc_72226 = DescrStatsW(notas72226.rating)

comparacao  = desc_72226.get_compare(desc_593)

print (comparacao.summary(use_t= True))
# Out:
#                           Test for equality of means
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1     -0.0780      0.208     -0.374      0.708      -0.488       0.332
# ...

# %%
#toy story e fantastic mr fox
desc_72226 = DescrStatsW(notas72226.rating)

comparacao  = desc_1.get_compare(desc_72226)

print (comparacao.summary(use_t=True))
# Out:
#                           Test for equality of means
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1     -0.1624      0.206     -0.788      0.431      -0.568       0.243
# ...

# %%
notas.query("movieId in (1, 593, 72226)").groupby("movieId").count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
from scipy.stats import normaltest
_, p = normaltest(notas1.rating)
print(p)
# Out:
# 0.00011053430732728716

# %%
from scipy.stats import ranksums

_, p = ranksums(notas1.rating, notas593.rating)
p
# Out:
# np.float64(0.0003267718756440693)
